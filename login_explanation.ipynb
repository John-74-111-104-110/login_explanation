# %%
print(ord('J'), ord('o'), ord('h'), ord('n'))
# Out:
# 74 111 104 110

# %%
print(chr(74), chr(111), chr(104), chr(110))
# Out:
# J o h n

# %% [markdown]
# ![login explanation.jpg](data:image/jpeg;base64,...)
